# %%
from planetsca import train

# %%
labeled_polygons_filepath = "./training_data/planetsca_training_data_polygons.geojson"
training_image_filepath = (
    "./training_data/20240116_170700_24_24b0_3B_AnalyticMS_SR_clip.tif"
)

# %%
training_data_df = train.data_training_new(
    labeled_polygons_filepath,
    training_image_filepath,
    training_data_filepath="my_training_data.csv",
)
# Out:
# Saving training data DataFrame to: my_training_data.csv

# %%
training_data_df.head()
# Out:
#      blue   green     red     nir  label
# 0  0.3814  0.3949  0.3867  0.4345      0
# 1  0.3843  0.3917  0.3815  0.4254      0
# 2  0.3790  0.3907  0.3750  0.4305      0
# 3  0.3828  0.3830  0.3826  0.4229      0
# 4  0.3821  0.3759  0.3877  0.4065      0

# %%
training_data_df.plot.scatter("nir", "blue", c="red")
# Out:
# <Axes: xlabel='nir', ylabel='blue'>
